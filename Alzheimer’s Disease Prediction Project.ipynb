# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/alzhemier.csv')

# %%
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       4751   73       0          0               2  22.927749        0
# 1       4752   89       0          0               0  26.827681        0
# 2       4753   73       0          3               1  17.795882        0
# 3       4754   74       1          0               1  33.800817        1
# 4       4755   89       0          0               0  20.716974        0
#
#    AlcoholConsumption  PhysicalActivity  DietQuality  ...  MemoryComplaints  \
# 0           13.297218          6.327112     1.347214  ...                 0
# 1            4.542524          7.619885     0.518767  ...                 0
# 2           19.555085          7.844988     1.826335  ...                 0
# 3           12.209266          8.428001     7.435604  ...                 0
# 4           18.454356          6.310461     0.795498  ...                 0
#
#    BehavioralProblems       ADL  Confusion  Disorientation  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PatientID                  2149 non-null   int64
#  1   Age                        2149 non-null   int64
#  2   Gender                     2149 non-null   int64
#  3   Ethnicity                  2149 non-null   int64
#  4   EducationLevel             2149 non-null   int64
#  5   BMI                        2149 non-null   float64
#  6   Smoking                    2149 non-null   int64
#  7   AlcoholConsumption         2149 non-null   float64
#  8   PhysicalActivity           2149 non-null   float64
#  9   DietQuality                2149 non-null   float64
#  10  SleepQuality               2149 non-null   float64
#  11  FamilyHistoryAlzheimers    2149 non-null   int64
#  12  CardiovascularDisease      2149 non-null   int64
# ...

# %%
df.describe()
# Out:
#          PatientID          Age       Gender    Ethnicity  EducationLevel  \
# count  2149.000000  2149.000000  2149.000000  2149.000000     2149.000000
# mean   5825.000000    74.908795     0.506282     0.697534        1.286645
# std     620.507185     8.990221     0.500077     0.996128        0.904527
# min    4751.000000    60.000000     0.000000     0.000000        0.000000
# 25%    5288.000000    67.000000     0.000000     0.000000        1.000000
# 50%    5825.000000    75.000000     1.000000     0.000000        1.000000
# 75%    6362.000000    83.000000     1.000000     1.000000        2.000000
# max    6899.000000    90.000000     1.000000     3.000000        3.000000
#
#                BMI      Smoking  AlcoholConsumption  PhysicalActivity  \
# count  2149.000000  2149.000000         2149.000000       2149.000000
# mean     27.655697     0.288506           10.039442          4.920202
# std       7.217438     0.453173            5.757910          2.857191
# ...

# %%
df.drop(columns=['PatientID'],inplace=True)

# %%
df['DoctorInCharge'].head()
# Out:
# 0    XXXConfid
# 1    XXXConfid
# 2    XXXConfid
# 3    XXXConfid
# 4    XXXConfid
# Name: DoctorInCharge, dtype: object

# %%
df.drop(columns='DoctorInCharge',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Age                        2149 non-null   int64
#  1   Gender                     2149 non-null   int64
#  2   Ethnicity                  2149 non-null   int64
#  3   EducationLevel             2149 non-null   int64
#  4   BMI                        2149 non-null   float64
#  5   Smoking                    2149 non-null   int64
#  6   AlcoholConsumption         2149 non-null   float64
#  7   PhysicalActivity           2149 non-null   float64
#  8   DietQuality                2149 non-null   float64
#  9   SleepQuality               2149 non-null   float64
#  10  FamilyHistoryAlzheimers    2149 non-null   int64
#  11  CardiovascularDisease      2149 non-null   int64
#  12  Diabetes                   2149 non-null   int64
# ...

# %%
plt.figure(figsize=(12, 10))  # Increase figure size for better clarity
sns.heatmap(df.corr())

plt.title('Correlation Heatmap', fontsize=16)  # Larger title font size
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Assuming df is your DataFrame
# 1. Standardize the data (it's important for PCA)
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)

# 2. Apply PCA
pca = PCA(n_components=2)  # You can change n_components based on how many components you want
pca_result = pca.fit_transform(df_scaled)

# 3. Create a DataFrame with the PCA result
pca_df = pd.DataFrame(data=pca_result, columns=['PC1', 'PC2'])

# 4. Visualize the explained variance ratio (optional)
plt.figure(figsize=(8, 6))
sns.barplot(x=[f'PC{i+1}' for i in range(len(pca.explained_variance_ratio_))],
            y=pca.explained_variance_ratio_)
plt.title('Explained Variance Ratio of PCA Components')
plt.show()

# 5. Plot the first two principal components
plt.figure(figsize=(8, 6))
sns.scatterplot(x='PC1', y='PC2', data=pca_df, hue=df['Diagnosis'])  # Assuming you have a 'Diagnosis' column
plt.title('PCA: First two Principal Components')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

X = df.drop(columns=['Diagnosis'])
y = df['Diagnosis']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
# Step 4: Split the data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

# %%
# Output the shape of the resulting splits
print(f"Training Features Shape: {X_train.shape}")
print(f"Test Features Shape: {X_test.shape}")
print(f"Training Target Shape: {y_train.shape}")
print(f"Test Target Shape: {y_test.shape}")
# Out:
# Training Features Shape: (1719, 2)
# Test Features Shape: (430, 2)
# Training Target Shape: (1719,)
# Test Target Shape: (430,)

# %% [markdown]
# decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
dt_pred = dt_model.predict(X_test)

# %%
print("Decision Tree Model Evaluation:")
print(f"Accuracy: {accuracy_score(y_test, dt_pred)}")
print("Confusion Matrix:\n", confusion_matrix(y_test, dt_pred))
print("Classification Report:\n", classification_report(y_test, dt_pred))
# Out:
# Decision Tree Model Evaluation:
# Accuracy: 0.6488372093023256
# Confusion Matrix:
#  [[210  67]
#  [ 84  69]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.76      0.74       277
#            1       0.51      0.45      0.48       153
#
#     accuracy                           0.65       430
#    macro avg       0.61      0.60      0.61       430
# weighted avg       0.64      0.65      0.64       430

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Make predictions on the test set
rf_pred = rf_model.predict(X_test)

# %%
# Evaluate Random Forest
print("\nRandom Forest Model Evaluation:")
print(f"Accuracy: {accuracy_score(y_test, rf_pred)}")
print("Confusion Matrix:\n", confusion_matrix(y_test, rf_pred))
print("Classification Report:\n", classification_report(y_test, rf_pred))
# Out:
# Random Forest Model Evaluation:
# Accuracy: 0.7162790697674418
# Confusion Matrix:
#  [[229  48]
#  [ 74  79]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.83      0.79       277
#            1       0.62      0.52      0.56       153
#
#     accuracy                           0.72       430
#    macro avg       0.69      0.67      0.68       430
# weighted avg       0.71      0.72      0.71       430

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC
from xgboost import XGBClassifier

# %%
svm_model = SVC(kernel='linear', random_state=42)  # You can experiment with different kernels like 'rbf'
svm_model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
# Make predictions on the test set
svm_pred = svm_model.predict(X_test)

# %%
# Evaluate SVM
print("Support Vector Machine (SVM) Model Evaluation:")
print(f"Accuracy: {accuracy_score(y_test, svm_pred)}")
print("Confusion Matrix:\n", confusion_matrix(y_test, svm_pred))
print("Classification Report:\n", classification_report(y_test, svm_pred))
# Out:
# Support Vector Machine (SVM) Model Evaluation:
# Accuracy: 0.7186046511627907
# Confusion Matrix:
#  [[245  32]
#  [ 89  64]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.88      0.80       277
#            1       0.67      0.42      0.51       153
#
#     accuracy                           0.72       430
#    macro avg       0.70      0.65      0.66       430
# weighted avg       0.71      0.72      0.70       430

# %% [markdown]
# Xboost

# %%
xgb_model = XGBClassifier(random_state=42)
xgb_model.fit(X_train, y_train)



xgb_pred = xgb_model.predict(X_test)

# %%
print("\nXGBoost Model Evaluation:")
print(f"Accuracy: {accuracy_score(y_test, xgb_pred)}")
print("Confusion Matrix:\n", confusion_matrix(y_test, xgb_pred))
print("Classification Report:\n", classification_report(y_test, xgb_pred))
# Out:
# XGBoost Model Evaluation:
# Accuracy: 0.6930232558139535
# Confusion Matrix:
#  [[225  52]
#  [ 80  73]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.81      0.77       277
#            1       0.58      0.48      0.53       153
#
#     accuracy                           0.69       430
#    macro avg       0.66      0.64      0.65       430
# weighted avg       0.68      0.69      0.68       430

# %% [markdown]
# grid search

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
# Set up the parameter grid for GridSearch
param_grid_svm = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf'],  # Try both linear and non-linear kernels
    'gamma': ['scale', 'auto', 0.1, 1, 10]
}

svm_grid_search = GridSearchCV(SVC(), param_grid_svm, cv=5, scoring='accuracy', verbose=1)
svm_grid_search.fit(X_train, y_train)

print("Best Parameters for SVM:", svm_grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# Best Parameters for SVM: {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
svm_best_model = svm_grid_search.best_estimator_
svm_pred_best = svm_best_model.predict(X_test)

# Evaluate the best model
print("Optimized SVM Model Evaluation:")
print(f"Accuracy: {accuracy_score(y_test, svm_pred_best)}")
print("Confusion Matrix:\n", confusion_matrix(y_test, svm_pred_best))
print("Classification Report:\n", classification_report(y_test, svm_pred_best))
# Out:
# Optimized SVM Model Evaluation:
# Accuracy: 0.713953488372093
# Confusion Matrix:
#  [[249  28]
#  [ 95  58]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.90      0.80       277
#            1       0.67      0.38      0.49       153
#
#     accuracy                           0.71       430
#    macro avg       0.70      0.64      0.64       430
# weighted avg       0.71      0.71      0.69       430

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

# Set up the parameter grid for GridSearch
param_grid_xgb = {
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7],
    'n_estimators': [100, 200, 300],
    'subsample': [0.8, 1],
    'colsample_bytree': [0.8, 1]
}

# GridSearch for XGBoost
xgb_grid_search = GridSearchCV(XGBClassifier(), param_grid_xgb, cv=5, scoring='accuracy', verbose=1)
xgb_grid_search.fit(X_train, y_train)

# Best hyperparameters from GridSearch
print("Best Parameters for XGBoost:", xgb_grid_search.best_params_)

# Train and predict with the best model
xgb_best_model = xgb_grid_search.best_estimator_
xgb_pred_best = xgb_best_model.predict(X_test)

# Evaluate the best model
print("\nOptimized XGBoost Model Evaluation:")
print(f"Accuracy: {accuracy_score(y_test, xgb_pred_best)}")
print("Confusion Matrix:\n", confusion_matrix(y_test, xgb_pred_best))
print("Classification Report:\n", classification_report(y_test, xgb_pred_best))
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Parameters for XGBoost: {'colsample_bytree': 1, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1}
#
# Optimized XGBoost Model Evaluation:
# Accuracy: 0.7046511627906977
# Confusion Matrix:
#  [[241  36]
#  [ 91  62]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.87      0.79       277
#            1       0.63      0.41      0.49       153
#
#     accuracy                           0.70       430
#    macro avg       0.68      0.64      0.64       430
# weighted avg       0.69      0.70      0.69       430

# %% [markdown]
# Without PCA

# %%
# Assuming you have a dataframe `df` with 'Diagnosis' as the target column
X = df.drop(columns=['Diagnosis'])  # Features
y = df['Diagnosis']  # Target

# %%
# Step 1: Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # Fit and transform the features

# Step 2: Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Step 3: Apply RandomForestClassifier
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)

# Step 4: Make predictions and evaluate
y_pred = clf.predict(X_test)

# Evaluate the accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of Random Forest Classifier: {accuracy * 100:.2f}%")
# Out:
# Accuracy of Random Forest Classifier: 92.56%

# %%
# Evaluate Random Forest
print("\nRandom Forest Model Evaluation:")
print("Confusion Matrix:\n", sns.heatmap(confusion_matrix(y_test, y_pred),annot=True))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Random Forest Model Evaluation:
# Confusion Matrix:
#  Axes(0.125,0.11;0.62x0.77)
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94       277
#            1       0.96      0.82      0.89       153
#
#     accuracy                           0.93       430
#    macro avg       0.94      0.90      0.92       430
# weighted avg       0.93      0.93      0.92       430

# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix


classifiers = {
    "Random Forest": RandomForestClassifier(random_state=42),
    "Logistic Regression": LogisticRegression(random_state=42),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Support Vector Machine": SVC(random_state=42)
}

# Step 4: Train each classifier, make predictions, and evaluate the accuracy
for name, clf in classifiers.items():
    clf.fit(X_train, y_train)  # Train the model
    y_pred = clf.predict(X_test)  # Make predictions

    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)  # Evaluate accuracy
    print(f"Accuracy of {name}: {accuracy * 100:.2f}%")

    # Calculate confusion matrix
    cm = confusion_matrix(y_test, y_pred)

    # Plot confusion matrix as heatmap
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Class 0', 'Class 1'], yticklabels=['Class 0', 'Class 1'])
    plt.title(f"Confusion Matrix for {name}")
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
# Out:
# Accuracy of Random Forest: 92.56%
# Accuracy of Logistic Regression: 83.02%
# Accuracy of K-Nearest Neighbors: 72.33%
# Accuracy of Support Vector Machine: 83.26%
